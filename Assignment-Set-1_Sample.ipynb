# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
import sys

# %%
print("Fatemeh Davari")
# Out:
# Fatemeh Davari

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0  1.204990 -0.007595  1.967613  0.936108
# 1 -1.192492 -1.195137 -0.051108 -0.892927
# 2 -0.108321 -0.345964  0.394016 -1.783768
# 3 -0.167039  1.707809  0.254449  0.617652
# 4 -0.093320  0.536245  1.424822 -0.937743
# 5 -1.563997 -0.820516 -0.150169 -0.043946
# 6 -2.561792  2.010057  0.660361 -0.309833
# 7 -1.074502 -0.303257 -1.231164 -0.253222
# 8  0.071440 -0.031174  0.159955  0.427955
# 9 -0.393316 -0.406287  0.711968  0.566488
#
# -> Execution Time = 19.1336088180542 in Seconds <-

# %%
print(sys.version)
# Out:
# 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]
